# %%
import pandas as pd
from statsmodels.api import OLS

# %%
df = pd.read_csv("../Data/Dataset.csv")
df = df.drop("Unnamed: 0", axis=1)
df
# Out:
#            Label (Grouping)  Unemployed  Government workers  \
# 0    Anderson County, Texas       0.017               0.227
# 1    Angelina County, Texas       0.037               0.176
# 2     Aransas County, Texas       0.040               0.180
# 3      Archer County, Texas       0.020               0.155
# 4    Atascosa County, Texas       0.037               0.176
# ..                      ...         ...                 ...
# 201      Wood County, Texas       0.022               0.155
# 202    Yoakum County, Texas       0.023               0.175
# 203     Young County, Texas       0.019               0.177
# 204    Zapata County, Texas       0.046               0.228
# 205    Zavala County, Texas       0.021               0.194
#
#      No health insurance coverage  Families w/ income below poverty  \
# 0                           0.169                             0.106
# 1                           0.192                             0.127
# 2                           0.160                             0.148
# 3                           0.168                             0.081
# 4                           0.195                             0.107
# ..                            ...                               ...
# 201                         0.159                             0.100
# 202                         0.247                             0.083
# 203                         0.184                             0.102
# 204                         0.260                             0.276
# 205                         0.141                             0.206
#
#      Married-couple household with children of the householder under 18 years  \
# 0                                                0.184
# 1                                                0.182
# 2                                                0.069
# 3                                                0.199
# 4                                                0.223
# ..                                                 ...
# 201                                              0.146
# 202                                              0.337
# 203                                              0.171
# 204                                              0.179
# 205                                              0.152
#
#      Bachelor's degree or higher  Residence 1 year ago in a different state  \
# 0                          0.120                                      0.008
# 1                          0.180                                      0.018
# 2                          0.248                                      0.018
# 3                          0.225                                      0.004
# 4                          0.148                                      0.006
# ..                           ...                                        ...
# 201                        0.204                                      0.020
# 202                        0.108                                      0.000
# 203                        0.257                                      0.015
# 204                        0.119                                      0.001
# 205                        0.148                                      0.002
#
#      Residence 1 year ago abroad  Foreign born  ...  \
# 0                          0.003         0.060  ...
# 1                          0.003         0.083  ...
# 2                          0.007         0.041  ...
# 3                          0.002         0.037  ...
# 4                          0.002         0.068  ...
# ..                           ...           ...  ...
# 201                        0.001         0.041  ...
# 202                        0.000         0.200  ...
# 203                        0.003         0.077  ...
# 204                        0.004         0.211  ...
# 205                        0.000         0.054  ...
#
#      Lacking complete plumbing facilities  Housing units with a mortgage  \
# 0                                   0.002                          0.430
# 1                                   0.002                          0.438
# 2                                   0.032                          0.334
# 3                                   0.012                          0.387
# 4                                   0.004                          0.413
# ..                                    ...                            ...
# 201                                 0.014                          0.403
# 202                                 0.000                          0.386
# 203                                 0.014                          0.383
# 204                                 0.000                          0.276
# 205                                 0.006                          0.126
#
#      SMOCAPI 35pct. or more for housing units with a mortgage  \
# 0                                                0.203
# 1                                                0.140
# 2                                                0.331
# 3                                                0.147
# 4                                                0.172
# ..                                                 ...
# 201                                              0.231
# 202                                              0.041
# 203                                              0.254
# 204                                              0.173
# 205                                              0.175
#
#      65 years and over  White non-Hispanics  \
# 0                0.145                0.573
# 1                0.162                0.597
# 2                0.273                0.663
# 3                0.202                0.877
# 4                0.147                0.319
# ..                 ...                  ...
# 201              0.265                0.814
# 202              0.090                0.288
# 203              0.204                0.770
# 204              0.133                0.034
# 205              0.148                0.054
#
#      $200,000 or more total household income  Mobile home  Homeowner vacancy  \
# 0                                      0.026        0.224              0.014
# 1                                      0.028        0.189              0.013
# 2                                      0.063        0.168              0.046
# 3                                      0.072        0.105              0.010
# 4                                      0.057        0.333              0.021
# ..                                       ...          ...                ...
# 201                                    0.047        0.171              0.006
# 202                                    0.103        0.150              0.000
# 203                                    0.035        0.080              0.010
# 204                                    0.032        0.253              0.009
# 205                                    0.011        0.281              0.002
#
#      SFHA Penetration Rate  Coastal County
# 0                    0.039             0.0
# 1                    0.192             0.0
# 2                    0.571             1.0
# 3                    0.413             0.0
# 4                    0.082             0.0
# ..                     ...             ...
# 201                  0.111             0.0
# 202                  0.164             0.0
# 203                  0.067             0.0
# 204                  0.031             0.0
# 205                  0.054             0.0
#
# [206 rows x 23 columns]

# %%
# Run model
X = df[["Unemployed",
"Government workers",
"No health insurance coverage",
"Families w/ income below poverty",
"Married-couple household with children of the householder under 18 years",
"Bachelor's degree or higher",
"Residence 1 year ago in a different state",
"Residence 1 year ago abroad",
"Foreign born",
"Vacant housing units",
"Built 1939 or earlier",
"Renteroccupied",
"Lacking complete plumbing facilities",
"Housing units with a mortgage",
"SMOCAPI 35pct. or more for housing units with a mortgage",
"65 years and over",
"White non-Hispanics",
"$200,000 or more total household income",
"Mobile home",
"Homeowner vacancy", 
"Coastal County"]]
y = df["SFHA Penetration Rate"]
OLS(y, X.astype(float)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     SFHA Penetration Rate   R-squared (uncentered):                   0.826
# Model:                               OLS   Adj. R-squared (uncentered):              0.806
# Method:                    Least Squares   F-statistic:                              41.79
# Date:                   Wed, 22 Mar 2023   Prob (F-statistic):                    6.96e-59
# Time:                           23:52:17   Log-Likelihood:                          210.29
# No. Observations:                    206   AIC:                                     -378.6
# Df Residuals:                        185   BIC:                                     -308.7
# Df Model:                             21
# Covariance Type:               nonrobust
# ============================================================================================================================================
#                                                                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------------------------
# Unemployed                                                                   0.3206      0.534      0.600      0.549      -0.733       1.374
# Government workers                                                           0.1404      0.154      0.912      0.363      -0.163       0.444
# No health insurance coverage                                                 0.0962      0.223      0.432      0.666      -0.343       0.536
# Families w/ income below poverty                                            -0.4280      0.191     -2.244      0.026      -0.804      -0.052
# Married-couple household with children of the householder under 18 years    -0.5636      0.187     -3.020      0.003      -0.932      -0.195
# Bachelor's degree or higher                                                  0.1131      0.165      0.686      0.493      -0.212       0.438
# Residence 1 year ago in a different state                                   -0.0343      0.808     -0.042      0.966      -1.628       1.560
# Residence 1 year ago abroad                                                 -1.1667      0.610     -1.911      0.057      -2.371       0.037
# Foreign born                                                                 0.0579      0.168      0.344      0.731      -0.274       0.390
# Vacant housing units                                                        -0.1900      0.130     -1.457      0.147      -0.447       0.067
# Built 1939 or earlier                                                       -0.1901      0.166     -1.149      0.252      -0.517       0.136
# Renteroccupied                                                               0.1347      0.113      1.195      0.234      -0.088       0.357
# Lacking complete plumbing facilities                                         2.8899      1.050      2.753      0.006       0.819       4.961
# Housing units with a mortgage                                                0.3287      0.106      3.091      0.002       0.119       0.539
# SMOCAPI 35pct. or more for housing units with a mortgage                     0.1127      0.104      1.082      0.281      -0.093       0.318
# 65 years and over                                                            0.1013      0.264      0.383      0.702      -0.420       0.623
# White non-Hispanics                                                         -0.0620      0.056     -1.103      0.271      -0.173       0.049
# $200,000 or more total household income                                      1.3550      0.362      3.744      0.000       0.641       2.069
# Mobile home                                                                  0.0802      0.123      0.654      0.514      -0.162       0.322
# Homeowner vacancy                                                            0.1750      0.580      0.302      0.763      -0.969       1.319
# Coastal County                                                               0.1583      0.027      5.943      0.000       0.106       0.211
# ==============================================================================
# Omnibus:                       56.131   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              127.491
# Skew:                           1.245   Prob(JB):                     2.07e-28
# Kurtosis:                       5.942   Cond. No.                         158.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
